# %%
#importing a module
import sys
print('nugget')
sys.exit()
print('nugget')

# %%
#See the traceback of the program
# %tb

# %%
#import pyperclip

# %%
#Function creation
def hello(name):
    print("helloman "+name)
    
hello('dillman')
# Out:
# helloman dillman

# %%
#Passing an arguement in a function
lol = 'spam'
def dillman():
    global lol
    lol='gharjao'
    print(lol)
    
print(lol)   
dillman()
print(lol)
# Out:
# spam
# gharjao
# gharjao

# %%
# for loops and if, elif
import random
print('enter your name')
name = input()
random_generated = random.randint(1,10)

for guesses in range(1,6):
    print('hey '+ name+ ' enter a random no. btw 1-10')
    random_no = int(input())
    
    if random_no == random_generated:
        print('yes! you have guessed correct')
        str_guesses = str(guesses)        
        print('it took you ' +str_guesses+' guesses') 
    elif random_no < random_generated:
        print('enter a higher no.')
    elif random_no > random_generated:
        print('enter a lower no.')
        
print('you didnt guess shit even after '+ str(guesses)+' attempts')
# Out:
# enter your name
# abhishek
# hey abhishek enter a random no. btw 1-10
# 3
# enter a lower no.
# hey abhishek enter a random no. btw 1-10
# 2
# yes! you have guessed correct
# it took you 2 guesses
# hey abhishek enter a random no. btw 1-10

# %%
# Palindrome by slicing
for attempts in range (100):
    print('enter the string to check for palindrome')
    pali_entr = input()
    if pali_entr == pali_entr[::-1]:
        print('its a palindrome')
    else:
        print('not a palindrome')

# %%
# lists in python
spam = ["gharojaobc","matjaobc","aajaobc", "kalaaobc"]
spam[1:3]
# Out:
# ['matjaobc', 'aajaobc']

# %%
# List slicing
ram = [1,2,3,4,5]
print(ram)
ram[1:2] = ['11','12','13','14']
print(ram, len(ram))

# sham = int(str(ram))
# sham

# %%
# 'in' keyword
c = '123'
d = list(c)
'1' in d
# Out:
# True

# %%
# Palindrome Program
print('enter the word')
name = input()
loop = list(name)
x = 0
for i in range(len(name)):
    if loop[i-1] != loop[-i]:
        x == '1'
    else:
        x == '2'

if x == 1:
    print('not a palindrome')
else: 
    print('a palindrome')
# Out:
# enter the word
# abhishek
# a palindrome

# %%
# List Iteration
list = ['1','2','3']
for i in range(len(list)):
    print('the index of list is '+ str(i)+'and item at that point is '+ list[i])
# Out:
# the index of list is 0and item at that point is 1
# the index of list is 1and item at that point is 2
# the index of list is 2and item at that point is 3

# %%
# List copy into another list
x,y,z = list
print(x+y+z)
t,p,r = '4','5','6'
print(t+p+r)
# Out:
# 123
# 456

# %%
# for loop +2 iteration
count=0
for i  in range(0,10,2):
    count+=1
    print(count)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# .append, .index, .insert, etc list functions
span = ['aditya','abhishek','nachiket']
span.append('gharjaobc')
span.index('aditya')
span.insert(1,'tau')
span = span.append('talwar')
print(span)
# Out:
# None

# %%
# Sort function in a list
list = ['abhishek','juned','raojeet','harpreet']
list.sort()
list
# Out:
# ['abhishek', 'harpreet', 'juned', 'raojeet']

# %%
# deletion function
del list[1]
list
# Out:
# ['abhishek', 'juned', 'raojeet']

# %%
# string slicing
str1 = 'name is abhishek'
str2 = str1[0:3]+'ely'+str1[4:12]
str2
# Out:
# 'namely is abhi'

# %%
# when you copy a list to another a reference is passed instead of the actual list so any change in one list will change the another
list1 = [1,2,3,4,5,6]
list2 = list1
list2.append(70)
print(list1,list2)
# Out:
# [1, 2, 3, 4, 5, 6, 70] [1, 2, 3, 4, 5, 6, 70]

# %%
# if you actually want to copy a list use this module
import copy
list3 = copy.deepcopy(list1)
list3.append(77)
print(list3)
print(list1)
# Out:
# [1, 2, 3, 4, 5, 6, 70, 77]
# [1, 2, 3, 4, 5, 6, 70]

# %%
# Dictionaries
dic = {'name':'abhishek','place':'california','program':'Masters'}
dic
# Out:
# {'name': 'abhishek', 'place': 'california', 'program': 'Masters'}

# %%
# try except statements: Put the box you think eill have error in try and put the response to that error in except
eggs = {'name':'abhishek', 'age': 19, 'Roll.no' : '8312'}

try:
    list(eggs.value())
except:
    print('no values')
    
print(list(eggs.keys())) 

for keys in eggs.keys():
    print(keys)
    
for key,values in eggs.items():
    print(key,values)
    
'name' in eggs.keys()
# Out:
# no values
# ['name', 'age', 'Roll.no']
# name
# age
# Roll.no
# name abhishek
# age 19
# Roll.no 8312
# True

# %%
# get values from dictionary
dic = {'class':8, 'rank':1, 'bhailog':'yes'}
print(dic.get('class','nahimila'))
dic.get('rude','nahimila')
# Out:
# 8
# 'nahimila'

# %%
# set default sets the value of any new occurence in dictionary to whatever we want (in this case 0)*****

str = '''May I have your attention, please?
May I have your attention, please?
Will the real Slim Shady please stand up?
I repeat, will the real Slim Shady please stand up?
We're gonna have a problem here
Y'all act like you never seen a white person before
Jaws all on the floor like Pam like Tommy just burst in the door
And started whoopin' her ass worse than before
They first were divorced, throwin' her over furniture (Agh!)
It's the return of the "Ah, wait, no way, you're kidding
He didn't just say what I think he did, did he?"
And Dr. Dre said, nothing, you idiots!
Dr. Dre's dead, he's locked in my basement (ha ha!)
Feminist women love Eminem
"Chicka, chicka, chicka, Slim Shady, I'm sick of him
Look at him, walkin' around, grabbin' his you-know-what
Flippin' the you-know-who, " "Yeah, but he's so cute though."
Yeah, I probably got a couple of screws up in my head loose
But no worse than what's goin' on in your parents' bedrooms
Sometimes I wanna get on TV and just let loose
But can't, but it's cool for Tom Green to hump a dead moose
"My bum is on your lips, my bum is on your lips"
And if I'm lucky, you might just give it a little kiss
And that's the message that we deliver to little kids
And expect them not to know what a woman's clitoris is
Of course they're gonna know what intercourse is
By the time they hit fourth grade
They've got the Discovery Channel, don't they?
We ain't nothin' but mammals—well, some of us, cannibals
Who cut other people open like cantaloupes
But if we can hump dead animals and antelopes
Then there's no reason that a man and another man can't elope
But if you feel like I feel, I got the antidote
Women, wave your pantyhose, sing the chorus, and it goes
I'm Slim Shady, yes I'm the real Shady
All you other Slim Shadys are just imitating
So won't the real Slim Shady please stand up
Please stand up, please stand up?
'Cause I'm Slim Shady, yes I'm the real Shady
All you other Slim Shadys are just imitating
So won't the real Slim Shady please stand up
Please stand up, please stand up?
Will Smith don't gotta cuss in his raps to sell records
Well, I do, so fuck him and fuck you too!
You think I give a damn about a Grammy?
Half of you critics can't even stomach me, let alone stand me
"But Slim, what if you win, wouldn't it be weird?"
Why, so you guys could just lie to get me here?
So you can sit me here next to Britney Spears?
Shit, Christina Aguilera better switch me chairs
So I can sit next to Carson Daly and Fred Durst
And hear 'em argue over who she gave head to first
Little bitch put me on blast on MTV
"Yeah, he's cute, but I think he's married to Kim, hee-hee."
I should download her audio on MP3
And show the whole world how you gave Eminem VD
I'm sick of you little girl and boy groups
All you do is annoy me, so I have been sent here to destroy you
And there's a million of us just like me
Who cuss like me, who just don't give a fuck like me
Who dress like me, walk, talk and act like me
And just might be the next best thing, but not quite me
'Cause I'm Slim Shady, yes I'm the real Shady
All you other Slim Shadys are just imitating
So won't the real Slim Shady please stand up
Please stand up, please stand up?
'Cause I'm Slim Shady, yes I'm the real Shady
All you other Slim Shadys are just imitating
So won't the real Slim Shady please stand up
Please stand up, please stand up?
I'm like a head trip to listen to, 'cause I'm only givin' you
Things you joke about with your friends inside your livin' room
The only difference is I got the balls to say it in front of y'all
And I don't gotta be false or sugarcoat it at all
I just get on the mic and spit it
And whether you like to admit it, I just shit it
Better than 90% of you rappers out can
Then you wonder: "How can
Kids eat up these albums like Valiums?"
It's funny, 'cause at the rate I'm going, when I'm 30
I'll be the only person in the nursing home flirting
Pinching nurse's asses when I'm jacking off with Jergens
And I'm jerking, but this whole bag of Viagra isn't working
And every single person is a Slim Shady lurking
He could be working at Burger King, spittin' on your onion rings
Or in the parking lot, circling, screaming, "I don't give a fuck!"
With his windows down and his system up
So will the real Shady please stand up
And put one of those fingers on each hand up?
And be proud to be outta your mind and outta control
And one more time, loud as you can, how does it go?
I'm Slim Shady, yes I'm the real Shady
All you other Slim Shadys are just imitating
So won't the real Slim Shady please stand up
Please stand up, please stand up?
'Cause I'm Slim Shady, yes I'm the real Shady
All you other Slim Shadys are just imitating
So won't the real Slim Shady please stand up
Please stand up, please stand up?
'Cause I'm Slim Shady, yes I'm the real Shady
All you other Slim Shadys are just imitating
So won't the real Slim Shady please stand up
Please stand up, please stand up?
'Cause I'm Slim Shady, yes I'm the real Shady
All you other Slim Shadys are just imitating
So won't the real Slim Shady please stand up
Please stand up, please stand up?
Ha ha, I guess there's a Slim Shady in all of us
Fuck it, let's all stand up!'''
dic1 = {}

for chr in str:
    dic1.setdefault(chr, 0)
    dic1[chr] = dic1[chr]+1
    
print(dic1)
# Out:
# {'M': 5, 'a': 312, 'y': 121, ' ': 900, 'I': 48, 'h': 207, 'v': 23, 'e': 411, 'o': 267, 'u': 169, 'r': 165, 't': 323, 'n': 244, 'i': 245, ',': 74, 'p': 88, 'l': 209, 's': 248, '?': 21, '\n': 108, 'W': 11, 'S': 83, 'm': 136, 'd': 159, 'w': 65, "'": 88, 'g': 69, 'b': 37, 'Y': 5, 'c': 63, 'k': 46, 'f': 42, 'J': 2, 'P': 11, 'T': 10, 'j': 21, 'A': 28, '(': 2, '!': 6, ')': 2, '"': 16, 'H': 5, 'D': 8, '.': 4, 'F': 4, 'E': 2, 'C': 10, 'L': 2, '-': 5, 'B': 9, 'V': 5, 'G': 2, 'x': 4, 'O': 2, '—': 1, 'K': 3, '3': 2, 'q': 1, '9': 1, '0': 2, '%': 1, ':': 1}

# %%
# basic upper case / lowercase functions
str1 ='abhishek'
'abhi' in str1
str1.upper()
str1.isalnum()
str1.isalpha()
str1.is
# Out:
# True

# %%
# checking functions
text1 = 'hello world'
text1.startswith('hello')
text1.endswith('world')
# Out:
# True

# %%
# string to list conversion word by word*****
string1 = "My name is abhishek ahirrao"
a = string1.split()
print(a)
b = ["mumbai", "is", "in", "maharashtra"]
','.join(b)
# <=====?
print(b)
paragraph = '''hey my name is abhishek 
i play cricket and workout every day 
this code is a lie and so is whatever'''
paragraph.split('\n')
paragraph.replace('abhishek','ayushi')
# Out:
# ['My', 'name', 'is', 'abhishek', 'ahirrao']
# ['mumbai', 'is', 'in', 'maharashtra']
# 'hey my name is ayushi \ni play cricket and workout every day \nthis code is a lie and so is whatever'

# %%
# recursion *****

# # 1,3,6,10,15,21,....
# def sum_till(n):
#     sum = 0
#     for i in range(1,n+1):
#         sum += i
#     return sum    
        
        
# def fibo(n):    
#     list1 = []
#     for i in range(1,n+1):
#         list1.append(sum_till(i))
#     print(list1)    
        
# fibo(6)  

def fibo(n):
    if(n == 0):
        print('end')
   
 elif(n == 1):
        return 1
    else:
        sum = fibo(n-1) + n
        print(sum)
    

fibo(5)

# %%
# regex eqns
import re

regex_object = re.compile(r"\d\d-\d\d\d\d\d\d\d\d\d\d")
# mo = regex_object.search("my phone number is +91-8928335999 and my phone no. is not +91-7774815152")
mo = regex_object.findall("my phone number is +91-8928335999 and my phone no. is not +91-7774815152")
# print(mo.group())
print(mo)
# Out:
# ['91-8928335999', '91-7774815152']

# %%
import re

regex_obj = re.compile(r"(\(\d\d\))-(\(\d\d\d\d\d\d\d\d\d\d\))")
mo = regex_obj.search("my phone number is +(91)-(8928335999) and my phone no. is not +91-7774815152")
print(mo.group(1,2))
# Out:
# ('(91)', '(8928335999)')

# %%
import re
regex_obj = re.compile(r"Bat(mobile|rat|man|agator)")
mo = regex_obj.search("Sasha where is my Batmobile as well as my Batagator")
print(mo.group())
# Out:
# Batmobile

# %%
# os module working finding file path, Currentworkingdir, etc

import os
print(os.path.join("folder1","folder2","app.js"))
os.sep
os.getcwd() 
# gets current working directory*/
os.chdir('c://')
os.getcwd()
os.path.abspath('app.js')
os.path.dirname('older1\folder2\app.js') 
# returns directory name
os.path.basename('app.js')
os.path.exists('C:\\Users\\ahirr\\Desktop\\CourseraApplication.txt')
os.path.isfile("C:\\Users\\ahirr\\Desktop\\CourseraApplication.txt")
os.path.isdir("C:\\Users\\ahirr\\Desktop")
# Out:
# folder1\folder2\app.js
# True

# %%
# count total size of a folder
import os
# total_files = os.listdir('D:\\Downloads')
# print(total_files)
# for files in total_files:
#     try:
#         print(files+" : ")
try:
    a = os.path.getsize("D:\\Downloads\\Paper-Summaries.pdf")
    b = str(a/(1024*1024))
    print(b+" Mb")
except:
    print("error")
#     except:
#         print('something is wrong')

files = os.listdir
# Out:
# 1.0334148406982422 Mb

# %%
# size of all files and folders in a folder

import os

os.chdir("D:\\Downloads")
T_files = os.listdir("D:\\Downloads")
sums = 0

for i in T_files:
    path = os.path.abspath(i)
    sums = sums + float(os.path.getsize(path)/(1024*1024))
    print(path+" : "+str(os.path.getsize(path)/(1024*1024))+" Mb")
print("totalsize ="+str(sums/1024)+" Gb")
# Out:
# D:\Downloads\(8317)Amurto Basu-20200331T114228Z-001.zip : 0.21235942840576172 Mb
# D:\Downloads\02Dataupdated (1).ppt : 3.97802734375 Mb
# D:\Downloads\02Dataupdated.ppt : 3.97998046875 Mb
# D:\Downloads\12-Rules-to-Learn-to-Code-eBook-Updated-26.11.18.pdf : 2.24501895904541 Mb
# totalsize =11.397936802357435 Gb

# %%
# Files in python

file = open("hello.txt", 'w')
file.write("is this visible?")
file = open("hello.txt",'r')
file.read()
file = open("hello.txt", 'w')
file.write("is previous values of this file wiped?")
file = open("hello.txt",'r')
file.read()
file = open("hello.txt",'a')
file.write("this should be appended")
file = open("hello.txt",'r')
file.read()
# Out:
# 'is previous values of this file wiped?this should be appended'

# %%
# copy folders

import shutil

# shutil.copy("C:\\Users\\ahirr\\Desktop\\Bhai\\app.py","C:\\Users\\ahirr\\Desktop\\lol")
# shutil.copytree("C:\\Users\\ahirr\\Desktop\\Bhai","C:\\Users\\ahirr\\Desktop\\ghata")
# Out:
# 'C:\\Users\\ahirr\\Desktop\\ghata'

# %%
import os,shutil
shutil.rmtree("C:\\Users\\ahirr\\Desktop\\Bhai")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-7ebd8c9f2a2a> in <module>
#       1 import os,shutil
# ----> 2 shutil.rmtree("C:\\Users\\ahirr\\Desktop\\Bhai")
#       3
#
# ~\Anaconda3\lib\shutil.py in rmtree(path, ignore_errors, onerror)
#     505             # can't continue even if onerror hook returns
#     506             return
# --> 507         return _rmtree_unsafe(path, onerror)
#     508
#     509 # Allow introspection of whether or not the hardening against symlink
#
# ~\Anaconda3\lib\shutil.py in _rmtree_unsafe(path, onerror)
#     366             entries = list(scandir_it)
#     367     except OSError:
# --> 368         onerror(os.scandir, path, sys.exc_info())
#     369         entries = []
#     370     for entry in entries:
#
# ~\Anaconda3\lib\shutil.py in _rmtree_unsafe(path, onerror)
#     363 def _rmtree_unsafe(path, onerror):
#     364     try:
# --> 365         with os.scandir(path) as scandir_it:
#     366             entries = list(scandir_it)
#     367     except OSError:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\ahirr\\Desktop\\Bhai'

# %%
# finding all folders and files in a folder *****

import os
os.chdir('c:\\')
for folderName, subfolders, filenames in os.walk('C:\\Users\\ahirr\\Desktop'):
        print("folders in main drive are "+ folderName)
        print("folders in "+(folderName)+" are "+str(subfolders))
#         print("files in "+(subfolders)+" are "+str((filesnames))
              
        for subfolder in subfolders:
              if 'fish' in subfolder:
                  os.rmdir("subfolder")
                  print(subfolder)
                    
        print('\n\n\n\n')                        

        for file in filenames:
              if file.endswith('.lproj'):
                  print('File we needed'+file)
# Out:
# folders in main drive are C:\Users\ahirr\Desktop
# folders in C:\Users\ahirr\Desktop are ['ascii', 'Bootstrap', 'BootstrapTemplates', 'Experiments', 'FlaskEnabledModel', 'Front-end-firebaseconnection', 'games', 'Machine Learning A-Z Template Folder', 'Medical_Website', 'MongoDB Compass', 'open_gl', 'Pca-ml', 'Pothole-Detection-master', 'Quickpdfs', 'udemy-downloader-gui-master']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\ascii
# folders in C:\Users\ahirr\Desktop\ascii are ['Sorting ']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\ascii\Sorting
# folders in C:\Users\ahirr\Desktop\ascii\Sorting  are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap
# folders in C:\Users\ahirr\Desktop\Bootstrap are ['bootstrap-4.4.1', 'TinDog-Start-master']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1 are ['.github', 'build', 'dist', 'js', 'nuget', 'scss', 'site']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\.github
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\.github are ['ISSUE_TEMPLATE', 'workflows']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\.github\ISSUE_TEMPLATE
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\.github\ISSUE_TEMPLATE are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\.github\workflows
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\.github\workflows are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\build
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\build are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\dist
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\dist are ['css', 'js']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\dist\css
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\dist\css are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\dist\js
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\dist\js are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\js
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\js are ['dist', 'src', 'tests']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\js\dist
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\js\dist are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\js\src
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\js\src are ['tools']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\js\src\tools
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\js\src\tools are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\js\tests
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\js\tests are ['integration', 'unit', 'visual']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\js\tests\integration
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\js\tests\integration are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\js\tests\unit
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\js\tests\unit are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\js\tests\visual
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\js\tests\visual are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\nuget
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\nuget are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\scss
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\scss are ['mixins', 'utilities', 'vendor']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\scss\mixins
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\scss\mixins are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\scss\utilities
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\scss\utilities are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\scss\vendor
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\scss\vendor are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site are ['docs', '_data', '_includes', '_layouts']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs are ['4.4']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4 are ['about', 'assets', 'components', 'content', 'examples', 'extend', 'getting-started', 'layout', 'utilities']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\about
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\about are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\assets
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\assets are ['brand', 'css', 'img', 'js', 'scss']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\assets\brand
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\assets\brand are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\assets\css
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\assets\css are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\assets\img
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\assets\img are ['examples', 'favicons']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\assets\img\examples
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\assets\img\examples are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\assets\img\favicons
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\assets\img\favicons are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\assets\js
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\assets\js are ['src', 'vendor']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\assets\js\src
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\assets\js\src are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\assets\js\vendor
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\assets\js\vendor are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\assets\scss
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\assets\scss are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\components
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\components are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\content
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\content are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples are ['album', 'blog', 'carousel', 'checkout', 'cover', 'dashboard', 'floating-labels', 'grid', 'jumbotron', 'navbar-bottom', 'navbar-fixed', 'navbar-static', 'navbars', 'offcanvas', 'pricing', 'product', 'sign-in', 'starter-template', 'sticky-footer', 'sticky-footer-navbar']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\album
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\album are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\blog
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\blog are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\carousel
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\carousel are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\checkout
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\checkout are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\cover
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\cover are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\dashboard
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\dashboard are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\floating-labels
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\floating-labels are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\grid
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\grid are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\jumbotron
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\jumbotron are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\navbar-bottom
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\navbar-bottom are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\navbar-fixed
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\navbar-fixed are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\navbar-static
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\navbar-static are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\navbars
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\navbars are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\offcanvas
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\offcanvas are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\pricing
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\pricing are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\product
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\product are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\sign-in
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\sign-in are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\starter-template
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\starter-template are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\sticky-footer
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\sticky-footer are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\sticky-footer-navbar
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\examples\sticky-footer-navbar are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\extend
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\extend are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\getting-started
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\getting-started are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\layout
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\layout are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\utilities
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\docs\4.4\utilities are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\_data
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\_data are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\_includes
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\_includes are ['icons']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\_includes\icons
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\_includes\icons are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\_layouts
# folders in C:\Users\ahirr\Desktop\Bootstrap\bootstrap-4.4.1\site\_layouts are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\TinDog-Start-master
# folders in C:\Users\ahirr\Desktop\Bootstrap\TinDog-Start-master are ['css', 'images']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\TinDog-Start-master\css
# folders in C:\Users\ahirr\Desktop\Bootstrap\TinDog-Start-master\css are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Bootstrap\TinDog-Start-master\images
# folders in C:\Users\ahirr\Desktop\Bootstrap\TinDog-Start-master\images are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates are ['Remember', 'startbootstrap-business-frontpage-gh-pages', 'startbootstrap-modern-business-gh-pages']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember are ['assets', 'forms']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets are ['css', 'img', 'js', 'vendor']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\css
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\css are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\img
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\img are ['portfolio', 'slide', 'team', 'testimonials']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\img\portfolio
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\img\portfolio are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\img\slide
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\img\slide are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\img\team
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\img\team are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\img\testimonials
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\img\testimonials are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\js
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\js are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor are ['aos', 'bootstrap', 'boxicons', 'counterup', 'icofont', 'isotope-layout', 'jquery', 'jquery-sticky', 'jquery.easing', 'owl.carousel', 'php-email-form', 'venobox', 'waypoints']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\aos
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\aos are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\bootstrap
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\bootstrap are ['css', 'js']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\bootstrap\css
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\bootstrap\css are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\bootstrap\js
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\bootstrap\js are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\boxicons
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\boxicons are ['css', 'fonts']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\boxicons\css
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\boxicons\css are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\boxicons\fonts
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\boxicons\fonts are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\counterup
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\counterup are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\icofont
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\icofont are ['fonts']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\icofont\fonts
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\icofont\fonts are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\isotope-layout
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\isotope-layout are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\jquery
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\jquery are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\jquery-sticky
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\jquery-sticky are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\jquery.easing
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\jquery.easing are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\owl.carousel
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\owl.carousel are ['assets']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\owl.carousel\assets
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\owl.carousel\assets are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\php-email-form
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\php-email-form are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\venobox
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\venobox are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\waypoints
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\assets\vendor\waypoints are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\forms
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\Remember\forms are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-business-frontpage-gh-pages
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-business-frontpage-gh-pages are ['css', 'vendor']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-business-frontpage-gh-pages\css
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-business-frontpage-gh-pages\css are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-business-frontpage-gh-pages\vendor
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-business-frontpage-gh-pages\vendor are ['bootstrap', 'jquery']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-business-frontpage-gh-pages\vendor\bootstrap
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-business-frontpage-gh-pages\vendor\bootstrap are ['css', 'js']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-business-frontpage-gh-pages\vendor\bootstrap\css
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-business-frontpage-gh-pages\vendor\bootstrap\css are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-business-frontpage-gh-pages\vendor\bootstrap\js
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-business-frontpage-gh-pages\vendor\bootstrap\js are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-business-frontpage-gh-pages\vendor\jquery
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-business-frontpage-gh-pages\vendor\jquery are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-modern-business-gh-pages
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-modern-business-gh-pages are ['css', 'js', 'mail', 'vendor']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-modern-business-gh-pages\css
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-modern-business-gh-pages\css are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-modern-business-gh-pages\js
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-modern-business-gh-pages\js are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-modern-business-gh-pages\mail
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-modern-business-gh-pages\mail are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-modern-business-gh-pages\vendor
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-modern-business-gh-pages\vendor are ['bootstrap', 'jquery']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-modern-business-gh-pages\vendor\bootstrap
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-modern-business-gh-pages\vendor\bootstrap are ['css', 'js']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-modern-business-gh-pages\vendor\bootstrap\css
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-modern-business-gh-pages\vendor\bootstrap\css are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-modern-business-gh-pages\vendor\bootstrap\js
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-modern-business-gh-pages\vendor\bootstrap\js are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-modern-business-gh-pages\vendor\jquery
# folders in C:\Users\ahirr\Desktop\BootstrapTemplates\startbootstrap-modern-business-gh-pages\vendor\jquery are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments
# folders in C:\Users\ahirr\Desktop\Experiments are ['CSS', 'DWM', 'SE']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\CSS
# folders in C:\Users\ahirr\Desktop\Experiments\CSS are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\DWM
# folders in C:\Users\ahirr\Desktop\Experiments\DWM are ['EXP 1', 'EXP 2', 'EXP 3', 'EXP 4', 'EXP 5', 'EXP 6', 'EXPERIMENT 10', 'EXPERIMENT 7', 'EXPERIMENT 8', 'EXPERIMENT 9', 'LAB MANUAL']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\DWM\EXP 1
# folders in C:\Users\ahirr\Desktop\Experiments\DWM\EXP 1 are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\DWM\EXP 2
# folders in C:\Users\ahirr\Desktop\Experiments\DWM\EXP 2 are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\DWM\EXP 3
# folders in C:\Users\ahirr\Desktop\Experiments\DWM\EXP 3 are ['OUTPUTS']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\DWM\EXP 3\OUTPUTS
# folders in C:\Users\ahirr\Desktop\Experiments\DWM\EXP 3\OUTPUTS are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\DWM\EXP 4
# folders in C:\Users\ahirr\Desktop\Experiments\DWM\EXP 4 are ['apriori library', 'apriori scratch']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\DWM\EXP 4\apriori library
# folders in C:\Users\ahirr\Desktop\Experiments\DWM\EXP 4\apriori library are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\DWM\EXP 4\apriori scratch
# folders in C:\Users\ahirr\Desktop\Experiments\DWM\EXP 4\apriori scratch are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\DWM\EXP 5
# folders in C:\Users\ahirr\Desktop\Experiments\DWM\EXP 5 are ['output']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\DWM\EXP 5\output
# folders in C:\Users\ahirr\Desktop\Experiments\DWM\EXP 5\output are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\DWM\EXP 6
# folders in C:\Users\ahirr\Desktop\Experiments\DWM\EXP 6 are ['baseball weka', 'housing weka', 'linear regression library', 'linear regression scratch']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\DWM\EXP 6\baseball weka
# folders in C:\Users\ahirr\Desktop\Experiments\DWM\EXP 6\baseball weka are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\DWM\EXP 6\housing weka
# folders in C:\Users\ahirr\Desktop\Experiments\DWM\EXP 6\housing weka are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\DWM\EXP 6\linear regression library
# folders in C:\Users\ahirr\Desktop\Experiments\DWM\EXP 6\linear regression library are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\DWM\EXP 6\linear regression scratch
# folders in C:\Users\ahirr\Desktop\Experiments\DWM\EXP 6\linear regression scratch are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\DWM\EXPERIMENT 10
# folders in C:\Users\ahirr\Desktop\Experiments\DWM\EXPERIMENT 10 are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\DWM\EXPERIMENT 7
# folders in C:\Users\ahirr\Desktop\Experiments\DWM\EXPERIMENT 7 are ['PART 1', 'PART 2']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\DWM\EXPERIMENT 7\PART 1
# folders in C:\Users\ahirr\Desktop\Experiments\DWM\EXPERIMENT 7\PART 1 are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\DWM\EXPERIMENT 7\PART 2
# folders in C:\Users\ahirr\Desktop\Experiments\DWM\EXPERIMENT 7\PART 2 are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\DWM\EXPERIMENT 8
# folders in C:\Users\ahirr\Desktop\Experiments\DWM\EXPERIMENT 8 are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\DWM\EXPERIMENT 9
# folders in C:\Users\ahirr\Desktop\Experiments\DWM\EXPERIMENT 9 are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\DWM\LAB MANUAL
# folders in C:\Users\ahirr\Desktop\Experiments\DWM\LAB MANUAL are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\SE
# folders in C:\Users\ahirr\Desktop\Experiments\SE are ['SE-Exp-List']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Experiments\SE\SE-Exp-List
# folders in C:\Users\ahirr\Desktop\Experiments\SE\SE-Exp-List are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\FlaskEnabledModel
# folders in C:\Users\ahirr\Desktop\FlaskEnabledModel are ['flask-safe', 'Object_Detection_demo_LIVE-master', '__pycache__']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\FlaskEnabledModel\flask-safe
# folders in C:\Users\ahirr\Desktop\FlaskEnabledModel\flask-safe are ['__pycache__']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\FlaskEnabledModel\flask-safe\__pycache__
# folders in C:\Users\ahirr\Desktop\FlaskEnabledModel\flask-safe\__pycache__ are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\FlaskEnabledModel\Object_Detection_demo_LIVE-master
# folders in C:\Users\ahirr\Desktop\FlaskEnabledModel\Object_Detection_demo_LIVE-master are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\FlaskEnabledModel\__pycache__
# folders in C:\Users\ahirr\Desktop\FlaskEnabledModel\__pycache__ are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Front-end-firebaseconnection
# folders in C:\Users\ahirr\Desktop\Front-end-firebaseconnection are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\games
# folders in C:\Users\ahirr\Desktop\games are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder are ['Part 0 - Welcome to Machine Learning A-Z', 'Part 1 - Data Preprocessing', 'Part 10 - Model Selection & Boosting', 'Part 2 - Regression', 'Part 3 - Classification', 'Part 4 - Clustering', 'Part 5 - Association Rule Learning', 'Part 6 - Reinforcement Learning', 'Part 7 - Natural Language Processing', 'Part 8 - Deep Learning', 'Part 9 - Dimensionality Reduction']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 0 - Welcome to Machine Learning A-Z
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 0 - Welcome to Machine Learning A-Z are ['Section 1 - Welcome to Machine Learning A-Z !']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 0 - Welcome to Machine Learning A-Z\Section 1 - Welcome to Machine Learning A-Z !
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 0 - Welcome to Machine Learning A-Z\Section 1 - Welcome to Machine Learning A-Z ! are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 1 - Data Preprocessing
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 1 - Data Preprocessing are ['Section 2 -------------------- Part 1 - Data Preprocessing --------------------']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 1 - Data Preprocessing\Section 2 -------------------- Part 1 - Data Preprocessing --------------------
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 1 - Data Preprocessing\Section 2 -------------------- Part 1 - Data Preprocessing -------------------- are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 10 - Model Selection & Boosting
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 10 - Model Selection & Boosting are ['Section 47 -------------------- Part 10 - Model Selection --------------------', 'Section 48 - Model Selection', 'Section 49 - XGBoost', 'Section 50 - Part Recap']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 10 - Model Selection & Boosting\Section 47 -------------------- Part 10 - Model Selection --------------------
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 10 - Model Selection & Boosting\Section 47 -------------------- Part 10 - Model Selection -------------------- are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 10 - Model Selection & Boosting\Section 48 - Model Selection
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 10 - Model Selection & Boosting\Section 48 - Model Selection are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 10 - Model Selection & Boosting\Section 49 - XGBoost
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 10 - Model Selection & Boosting\Section 49 - XGBoost are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 10 - Model Selection & Boosting\Section 50 - Part Recap
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 10 - Model Selection & Boosting\Section 50 - Part Recap are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression are ['Section 10 - Evaluating Regression Models Performance', 'Section 11 - Regularization Methods', 'Section 12 - Part Recap', 'Section 3 -------------------- Part 2 - Regression --------------------', 'Section 4 - Simple Linear Regression', 'Section 5 - Multiple Linear Regression', 'Section 6 - Polynomial Regression', 'Section 7 - Support Vector Regression (SVR)', 'Section 8 - Decision Tree Regression', 'Section 9 - Random Forest Regression']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 10 - Evaluating Regression Models Performance
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 10 - Evaluating Regression Models Performance are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 11 - Regularization Methods
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 11 - Regularization Methods are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 12 - Part Recap
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 12 - Part Recap are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 3 -------------------- Part 2 - Regression --------------------
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 3 -------------------- Part 2 - Regression -------------------- are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 4 - Simple Linear Regression
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 4 - Simple Linear Regression are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 5 - Multiple Linear Regression
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 5 - Multiple Linear Regression are ['Homework_Solutions', 'Multiple_Linear_Regression', '__MACOSX']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 5 - Multiple Linear Regression\Homework_Solutions
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 5 - Multiple Linear Regression\Homework_Solutions are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 5 - Multiple Linear Regression\Multiple_Linear_Regression
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 5 - Multiple Linear Regression\Multiple_Linear_Regression are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 5 - Multiple Linear Regression\__MACOSX
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 5 - Multiple Linear Regression\__MACOSX are ['Homework_Solutions', 'Multiple_Linear_Regression']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 5 - Multiple Linear Regression\__MACOSX\Homework_Solutions
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 5 - Multiple Linear Regression\__MACOSX\Homework_Solutions are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 5 - Multiple Linear Regression\__MACOSX\Multiple_Linear_Regression
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 5 - Multiple Linear Regression\__MACOSX\Multiple_Linear_Regression are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 6 - Polynomial Regression
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 6 - Polynomial Regression are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 7 - Support Vector Regression (SVR)
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 7 - Support Vector Regression (SVR) are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 8 - Decision Tree Regression
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 8 - Decision Tree Regression are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 9 - Random Forest Regression
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 9 - Random Forest Regression are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 3 - Classification
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 3 - Classification are ['Section 13 -------------------- Part 3 - Classification --------------------', 'Section 14 - Logistic Regression', 'Section 15 - K-Nearest Neighbors (K-NN)', 'Section 16 - Support Vector Machine (SVM)', 'Section 17 - Kernel SVM', 'Section 18 - Naive Bayes', 'Section 19 - Decision Tree Classification', 'Section 20 - Random Forest Classification', 'Section 21 - Evaluating Classification Models Performance', 'Section 22 - Part Recap']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 3 - Classification\Section 13 -------------------- Part 3 - Classification --------------------
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 3 - Classification\Section 13 -------------------- Part 3 - Classification -------------------- are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 3 - Classification\Section 14 - Logistic Regression
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 3 - Classification\Section 14 - Logistic Regression are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 3 - Classification\Section 15 - K-Nearest Neighbors (K-NN)
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 3 - Classification\Section 15 - K-Nearest Neighbors (K-NN) are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 3 - Classification\Section 16 - Support Vector Machine (SVM)
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 3 - Classification\Section 16 - Support Vector Machine (SVM) are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 3 - Classification\Section 17 - Kernel SVM
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 3 - Classification\Section 17 - Kernel SVM are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 3 - Classification\Section 18 - Naive Bayes
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 3 - Classification\Section 18 - Naive Bayes are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 3 - Classification\Section 19 - Decision Tree Classification
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 3 - Classification\Section 19 - Decision Tree Classification are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 3 - Classification\Section 20 - Random Forest Classification
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 3 - Classification\Section 20 - Random Forest Classification are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 3 - Classification\Section 21 - Evaluating Classification Models Performance
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 3 - Classification\Section 21 - Evaluating Classification Models Performance are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 3 - Classification\Section 22 - Part Recap
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 3 - Classification\Section 22 - Part Recap are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 4 - Clustering
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 4 - Clustering are ['Section 23 -------------------- Part 4 - Clustering --------------------', 'Section 24 - K-Means Clustering', 'Section 25 - Hierarchical Clustering', 'Section 26 - Part Recap']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 4 - Clustering\Section 23 -------------------- Part 4 - Clustering --------------------
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 4 - Clustering\Section 23 -------------------- Part 4 - Clustering -------------------- are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 4 - Clustering\Section 24 - K-Means Clustering
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 4 - Clustering\Section 24 - K-Means Clustering are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 4 - Clustering\Section 25 - Hierarchical Clustering
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 4 - Clustering\Section 25 - Hierarchical Clustering are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 4 - Clustering\Section 26 - Part Recap
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 4 - Clustering\Section 26 - Part Recap are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 5 - Association Rule Learning
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 5 - Association Rule Learning are ['Section 27 -------------------- Part 5 - Association Rule Learning --------------------', 'Section 28 - Apriori', 'Section 29 - Eclat', 'Section 30 - Part Recap']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 5 - Association Rule Learning\Section 27 -------------------- Part 5 - Association Rule Learning --------------------
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 5 - Association Rule Learning\Section 27 -------------------- Part 5 - Association Rule Learning -------------------- are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 5 - Association Rule Learning\Section 28 - Apriori
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 5 - Association Rule Learning\Section 28 - Apriori are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 5 - Association Rule Learning\Section 29 - Eclat
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 5 - Association Rule Learning\Section 29 - Eclat are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 5 - Association Rule Learning\Section 30 - Part Recap
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 5 - Association Rule Learning\Section 30 - Part Recap are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 6 - Reinforcement Learning
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 6 - Reinforcement Learning are ['Section 31 -------------------- Part 6 - Reinforcement Learning --------------------', 'Section 32 - Upper Confidence Bound (UCB)', 'Section 33 - Thompson Sampling', 'Section 34 - Part Recap']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 6 - Reinforcement Learning\Section 31 -------------------- Part 6 - Reinforcement Learning --------------------
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 6 - Reinforcement Learning\Section 31 -------------------- Part 6 - Reinforcement Learning -------------------- are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 6 - Reinforcement Learning\Section 32 - Upper Confidence Bound (UCB)
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 6 - Reinforcement Learning\Section 32 - Upper Confidence Bound (UCB) are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 6 - Reinforcement Learning\Section 33 - Thompson Sampling
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 6 - Reinforcement Learning\Section 33 - Thompson Sampling are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 6 - Reinforcement Learning\Section 34 - Part Recap
# folders in C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 6 - Reinforcement Learning\Section 34 - Part Recap are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Machine Learning A-Z Template Folder\Part 7 - Natural Language Processing
# ...
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\fsevents\build
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\fsevents\build are ['Release']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\fsevents\build\Release
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\fsevents\build\Release are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\fsevents\lib
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\fsevents\lib are ['binding']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\fsevents\lib\binding
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\fsevents\lib\binding are ['Release']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\fsevents\lib\binding\Release
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\fsevents\lib\binding\Release are ['electron-v3.1-darwin-x64', 'node-v64-darwin-x64']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\fsevents\lib\binding\Release\electron-v3.1-darwin-x64
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\fsevents\lib\binding\Release\electron-v3.1-darwin-x64 are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\fsevents\lib\binding\Release\node-v64-darwin-x64
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\fsevents\lib\binding\Release\node-v64-darwin-x64 are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\kerberos
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\kerberos are ['bin', 'build']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\kerberos\bin
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\kerberos\bin are ['darwin-x64-64']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\kerberos\bin\darwin-x64-64
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\kerberos\bin\darwin-x64-64 are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\kerberos\build
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\kerberos\build are ['Release']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\kerberos\build\Release
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\kerberos\build\Release are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\keytar
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\keytar are ['build']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\keytar\build
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\keytar\build are ['Release']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\keytar\build\Release
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\keytar\build\Release are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\parse-json
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\parse-json are ['vendor']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\parse-json\vendor
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\parse-json\vendor are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\react-virtualized
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\react-virtualized are ['dist']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\react-virtualized\dist
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\react-virtualized\dist are ['commonjs', 'es']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\react-virtualized\dist\commonjs
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\react-virtualized\dist\commonjs are ['vendor']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\react-virtualized\dist\commonjs\vendor
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\react-virtualized\dist\commonjs\vendor are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\react-virtualized\dist\es
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\react-virtualized\dist\es are ['vendor']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\react-virtualized\dist\es\vendor
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\react-virtualized\dist\es\vendor are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\spawn-rx
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\spawn-rx are ['vendor']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\spawn-rx\vendor
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\spawn-rx\vendor are ['jobber']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\spawn-rx\vendor\jobber
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\spawn-rx\vendor\jobber are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\triejs
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\triejs are ['tests']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\triejs\tests
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\triejs\tests are ['vendor']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\triejs\tests\vendor
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\triejs\tests\vendor are ['foounit']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\triejs\tests\vendor\foounit
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\Resources\app.asar.unpacked\node_modules\triejs\tests\vendor\foounit are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\_CodeSignature
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\MongoDB Compass.app\Contents\_CodeSignature are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\MongoDB Compass\[HFS+ Private Data]
# folders in C:\Users\ahirr\Desktop\MongoDB Compass\[HFS+ Private Data] are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl
# folders in C:\Users\ahirr\Desktop\open_gl are ['freeglut', 'glew-1.11.0']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl\freeglut
# folders in C:\Users\ahirr\Desktop\open_gl\freeglut are ['bin', 'include', 'lib']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl\freeglut\bin
# folders in C:\Users\ahirr\Desktop\open_gl\freeglut\bin are ['x64']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl\freeglut\bin\x64
# folders in C:\Users\ahirr\Desktop\open_gl\freeglut\bin\x64 are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl\freeglut\include
# folders in C:\Users\ahirr\Desktop\open_gl\freeglut\include are ['GL']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl\freeglut\include\GL
# folders in C:\Users\ahirr\Desktop\open_gl\freeglut\include\GL are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl\freeglut\lib
# folders in C:\Users\ahirr\Desktop\open_gl\freeglut\lib are ['x64']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl\freeglut\lib\x64
# folders in C:\Users\ahirr\Desktop\open_gl\freeglut\lib\x64 are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl\glew-1.11.0
# folders in C:\Users\ahirr\Desktop\open_gl\glew-1.11.0 are ['bin', 'doc', 'include', 'lib']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\bin
# folders in C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\bin are ['Release', 'Release MX']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\bin\Release
# folders in C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\bin\Release are ['Win32', 'x64']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\bin\Release\Win32
# folders in C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\bin\Release\Win32 are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\bin\Release\x64
# folders in C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\bin\Release\x64 are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\bin\Release MX
# folders in C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\bin\Release MX are ['Win32', 'x64']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\bin\Release MX\Win32
# folders in C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\bin\Release MX\Win32 are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\bin\Release MX\x64
# folders in C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\bin\Release MX\x64 are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\doc
# folders in C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\doc are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\include
# folders in C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\include are ['GL']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\include\GL
# folders in C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\include\GL are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\lib
# folders in C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\lib are ['Release MX']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\lib\Release MX
# folders in C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\lib\Release MX are ['Win32', 'x64']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\lib\Release MX\Win32
# folders in C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\lib\Release MX\Win32 are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\lib\Release MX\x64
# folders in C:\Users\ahirr\Desktop\open_gl\glew-1.11.0\lib\Release MX\x64 are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Pca-ml
# folders in C:\Users\ahirr\Desktop\Pca-ml are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Pothole-Detection-master
# folders in C:\Users\ahirr\Desktop\Pothole-Detection-master are ['Pothole_Detection']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Pothole-Detection-master\Pothole_Detection
# folders in C:\Users\ahirr\Desktop\Pothole-Detection-master\Pothole_Detection are ['.ipynb_checkpoints']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\Pothole-Detection-master\Pothole_Detection\.ipynb_checkpoints
# folders in C:\Users\ahirr\Desktop\Pothole-Detection-master\Pothole_Detection\.ipynb_checkpoints are []
# folders in main drive are C:\Users\ahirr\Desktop\Quickpdfs
# folders in C:\Users\ahirr\Desktop\Quickpdfs are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\udemy-downloader-gui-master
# folders in C:\Users\ahirr\Desktop\udemy-downloader-gui-master are ['.github', 'assets', 'locale']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\udemy-downloader-gui-master\.github
# folders in C:\Users\ahirr\Desktop\udemy-downloader-gui-master\.github are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\udemy-downloader-gui-master\assets
# folders in C:\Users\ahirr\Desktop\udemy-downloader-gui-master\assets are ['css', 'fonts', 'images', 'js']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\udemy-downloader-gui-master\assets\css
# folders in C:\Users\ahirr\Desktop\udemy-downloader-gui-master\assets\css are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\udemy-downloader-gui-master\assets\fonts
# folders in C:\Users\ahirr\Desktop\udemy-downloader-gui-master\assets\fonts are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\udemy-downloader-gui-master\assets\images
# folders in C:\Users\ahirr\Desktop\udemy-downloader-gui-master\assets\images are ['build']
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\udemy-downloader-gui-master\assets\images\build
# folders in C:\Users\ahirr\Desktop\udemy-downloader-gui-master\assets\images\build are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\udemy-downloader-gui-master\assets\js
# folders in C:\Users\ahirr\Desktop\udemy-downloader-gui-master\assets\js are []
#
#
#
#
#
# folders in main drive are C:\Users\ahirr\Desktop\udemy-downloader-gui-master\locale
# folders in C:\Users\ahirr\Desktop\udemy-downloader-gui-master\locale are []

# %%
# how to save a traceback in a separate file and 'raise' statement which raises a error

import traceback
import os
print(os.getcwd())
try:
    raise Exception('This is a error message')
except:
    errorFile = open("error_log.txt", 'a')
    errorFile.write(traceback.format_exc())
    errorFile.close()
    print('the traceback is saved in a txt file')
# Out:
# C:\Users\ahirr
# the traceback is saved in a txt file

# %%
assert "anything in your code that is absolutely true"

# %%
# Instead of print to check the working of prog use this Debugging
import logging
logging.basicConfig(filename="myLogs.txt" level=logging.DEBUG, format ='%(asctime)s - %(levelname)s - %(message)s')
# to disable logging messages
logging.disable()
#levels of logging message
logging.debug()
logging.info()
logging.warning()
logging.critical()
logging.error()

# %%
# see the debugger gui in python : Debugger
# %debug
def blah():
    print('blah')
    print('blah')
    print('blah')
    modeblah()
    print('blah')
    print('blah')

def moreblah():
    print('blah')
    print('blah')
    print('blah')

blah()
# Out:
# > c:\users\ahirr\anaconda3\lib\site-packages\ipython\core\compilerop.py(100)ast_parse()
#      98         Arguments are exactly the same as ast.parse (in the standard library),
#      99         and are passed to the built-in compile function."""
# --> 100         return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#     101
#     102     def reset_compiler_flags(self):
#
# ipdb> 1
# 1
# ipdb> 2
# 2
# ipdb> 3
# 3
# ipdb> 4
# 4

# %%
# opening a webbrowser and passing a args from cmd

import webbrowser, sys
sys.argv
print(sys.argv)

if len(sys.argv) > 1:
    address = ''.join(sys.argv[1:])
#     after 1 because, we pass a cmd 'x.py' to run the program at 1st index and after that we pass arguements onwards
else:
    address = 'alabama'
print(address)
webbrowser.open('https://www.google.com/maps/place/'+address)
# Out:
# ['C:\\Users\\ahirr\\Anaconda3\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\ahirr\\AppData\\Roaming\\jupyter\\runtime\\kernel-87bff883-834a-468b-8b42-547f0a6d2367.json']
# -fC:\Users\ahirr\AppData\Roaming\jupyter\runtime\kernel-87bff883-834a-468b-8b42-547f0a6d2367.json
# True

# %%
# get a file from the website and write it into a txt file 'Web scraping'

import requests, os
res = requests.get('https://automatetheboringstuff.com/files/rj.txt')
print(res.status_code)
# print(res.text)
# tells false if any problem occur with res
res.raise_for_status()
print(os.getcwd())
file = open('rnj.txt', 'wb')
for chunk in res.iter_content(10000):
    file.write(chunk)
# Out:
# 200
# C:\Users\ahirr

# %%
# web scraping Get prices from flipkart
import bs4, requests

def getflipkartprices(productURL):
    res = requests.get(productURL)
    res.raise_for_status()
    
    soup = bs4.BeautifulSoup(res.text)
    elems = soup.select('#CSS format')
    return elems[0].text.strip()

price = getflipkartprice('#pass product url')    
print('the price is +price')

# %%
#selenium helps control web browser.

# %%
# !pip install openpyxl
#Excel Sheets
import openpyxl
import os
# os.chdir('C:\\Users\\ahirr\\Desktop')
# print(os.getcwd())
# workbook = openpyxl.load_workbook('example.xlsx')
# # print(os.getcwd())

# ************************ The module openpyxl not working *******************************
# Out:
# Requirement already satisfied: openpyxl in c:\users\ahirr\anaconda3\lib\site-packages (2.5.12)
# Requirement already satisfied: et-xmlfile in c:\users\ahirr\anaconda3\lib\site-packages (from openpyxl) (1.0.1)
# Requirement already satisfied: jdcal in c:\users\ahirr\anaconda3\lib\site-packages (from openpyxl) (1.4)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-989c5e595fc3> in <module>
#       1 get_ipython().system('pip install openpyxl')
#       2 #Excel Sheets
# ----> 3 import openpyxl
#       4 import os
#       5 # os.chdir('C:\\Users\\ahirr\\Desktop')
#
# ~\Anaconda3\lib\site-packages\openpyxl\__init__.py in <module>
#       2
#       3
# ----> 4 from openpyxl.compat.numbers import NUMPY, PANDAS
#       5 from openpyxl.xml import DEFUSEDXML, LXML
#       6 from openpyxl.workbook import Workbook
#
# ~\Anaconda3\lib\site-packages\openpyxl\compat\__init__.py in <module>
#       3
#       4
# ----> 5 from .strings import (
#       6     basestring,
#       7     unicode,
#
# ~\Anaconda3\lib\site-packages\openpyxl\compat\strings.py in <module>
#       8 VER = sys.version_info
#       9
# ---> 10 from .numbers import NUMERIC_TYPES
#      11
#      12 if VER[0] >= 3:
#
# ~\Anaconda3\lib\site-packages\openpyxl\compat\numbers.py in <module>
#      26
#      27 try:
# ---> 28     import pandas
#      29     PANDAS = True
#      30 except ImportError:
#
# ~\Anaconda3\lib\site-packages\pandas\__init__.py in <module>
#      29
#      30 try:
# ---> 31     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#      32 except ImportError as e:  # pragma: no cover
#      33     # hack but overkill to use re
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\__init__.py in <module>
#       1 # flake8: noqa
#       2
# ----> 3 from .tslibs import (
#       4     NaT,
#       5     NaTType,
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\tslibs\__init__.py in <module>
#       1 # flake8: noqa
#       2
# ----> 3 from .conversion import localize_pydatetime, normalize_date
#       4 from .nattype import NaT, NaTType, iNaT, is_null_datetimelike
#       5 from .np_datetime import OutOfBoundsDatetime
#
# pandas\_libs\tslibs\conversion.pyx in init pandas._libs.tslibs.conversion()
#
# AttributeError: type object 'pandas._libs.tslibs.conversion._TSObject' has no attribute '__reduce_cython__'

# %%
#***************Emails using python************************

import smtplib

conn = smtplib.SMTP('smtp.gmail.com', 587)
print(type(conn))
conn.ehlo()
conn.starttls()
conn.login("ahirraoabhishek007@gmail.com", "vglpcmfzlcllfzmw")
conn.sendmail('ahirraoabhishek007@gmail.com','ahirraoabhishek007@outlook.com', 'Subject: Hey python coder boi \n\n Worked? \n\n-Abhi')
conn.quit()
# Out:
# <class 'smtplib.SMTP'>
# (221, b'2.0.0 closing connection q201sm2945021pfq.40 - gsmtp')

# %%
# retrieving info from mail
# pip install imapclient pyzmail
import imapclient
conn = imapclient.IMAPClient('imap.gmail.com', ssl=True)
conn.login('ahirraoabhishek007@gmail.com','vglpcmfzlcllfzmw')
conn.select_folder('INBOX', readonly = True)
UIDs = conn.search(['UNSEEN'])
UIDs
conn.fetch([986],['BODY[]','FLAGS'])

import pyzmail

message = pyzmail.PyzMessage.factory(rawMessage[986][b'BODY[]'])
print(message)              
#problem using pyzmail
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-4aedbb11c553> in <module>
#       8 conn.fetch([986],['BODY[]','FLAGS'])
#       9
# ---> 10 import pyzmail
#      11
#      12 message = pyzmail.PyzMessage.factory(rawMessage[986][b'BODY[]'])
#
# ModuleNotFoundError: No module named 'pyzmail'
